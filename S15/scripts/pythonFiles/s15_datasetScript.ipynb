# %%
import os,sys,gc
from pathlib import Path
from google.colab import files
from IPython.core.debugger import set_trace
gc.enable()
gc.collect()
gc.get_threshold()
# Out:
# (700, 10, 10)

# %%
homepath = '/content/drive/My Drive/EVA4/S15'
dspath   = '/content/drive/My Drive/EVA4/S15/dataset'
zipFilesPath = '/content/drive/My Drive/EVA4/S15/dataset/zipFiles'
scriptsPath  = '/content/drive/My Drive/EVA4/S15/scripts'

sys.path.append(homepath)
sys.path.append(dspath)
sys.path.append(zipFilesPath)
sys.path.append(scriptsPath)

# %%
# !pip install ipython-autotime
# %load_ext autotime

# %% [markdown]
# # Hardware details

# %%
import torch
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.0+cu101 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)
# time: 3.05 s

# %% [markdown]
# # Upload modified overlay script

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))

if os.path.exists('s15_datasetScript.py'):
    os.remove('s15_datasetScript.py')
src = list(files.upload().values())[0]
open('s15_datasetScript.py','wb').write(src)
# Out:
#      <input type="file" id="files-caaaeaba-c835-45a2-a779-55fed949ae53" name="files[]" multiple disabled />
#      <output id="result-caaaeaba-c835-45a2-a779-55fed949ae53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving s15_datasetScript.py to s15_datasetScript.py
# 12727
# time: 8.23 s

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))

if os.path.exists('generatePkl_fromCustomDataset.py'):
    os.remove('generatePkl_fromCustomDataset.py')
src = list(files.upload().values())[0]
open('generatePkl_fromCustomDataset.py','wb').write(src)
# Out:
#      <input type="file" id="files-377f747d-3079-46ef-bea3-babbad1f5969" name="files[]" multiple disabled />
#      <output id="result-377f747d-3079-46ef-bea3-babbad1f5969">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving generatePkl_fromCustomDataset.py to generatePkl_fromCustomDataset.py
# 4214
# time: 8.46 s

# %%
os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')

if os.path.exists('test.py'):
    os.remove('test.py')
src = list(files.upload().values())[0]
open('test.py','wb').write(src)
# Out:
#      <input type="file" id="files-e46f64cf-37d7-408a-bc1a-55b6824249ac" name="files[]" multiple disabled />
#      <output id="result-e46f64cf-37d7-408a-bc1a-55b6824249ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.py to test.py
# 3253
# time: 16.9 s

# %%
os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')

if os.path.exists('utils.py'):
    os.remove('utils.py')
src = list(files.upload().values())[0]
open('utils.py','wb').write(src)
# Out:
#      <input type="file" id="files-5d02101f-d73c-4d47-8cdd-d0a90fd1c7de" name="files[]" multiple disabled />
#      <output id="result-5d02101f-d73c-4d47-8cdd-d0a90fd1c7de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving utils.py to utils.py
# 13344
# time: 14 s

# %% [markdown]
# # Import trained model weights

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./nyu.h5

# %% [markdown]
# # Dataset Generation commands:
#
# ---
# ## Comands to generate dataset:
#
#
# *   BGFG+Mask:
#         os.chdir(os.path.join(scriptsPath,'pythonFiles'))
#         !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -s 1 -e 6 -bf 1 -bfm 1
# *   Depth Map output in batches:
#         os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
#         !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 0 -re 5001 -b 50
#         !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 5000 -re 10001 -b 50
#         !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 10000 -re 15001 -b 50
#         !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 15000 -re 20001 -b 50

# %% [markdown]
# ## batch-1 :

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -s 1 -e 6 -bf 1 -bfm 1
# Out:
# 1 6
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip
# Using background : 1
# 500
# 1000
# 1500
# 2000
# Using background : 2
# 500
# 1000
# 1500
# 2000
# Using background : 3
# 500
# 1000
# 1500
# 2000
# Using background : 4
# 500
# 1000
# 1500
# 2000
# Using background : 5
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:06.827915
# time: 2min 10s

# %%
os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 0     -re 5001 -b  100
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 5001  -re 10001 -b 100
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 10001 -re 15001 -b 100
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -rs 15001 -re 20001 -b 100
# Out:
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.262104
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdc69e000 @  0x7f1c718fe1e7 0x7f1c6e2f35e1 0x7f1c6e357c78 0x7f1c6e357d93 0x7f1c6e3f5ea8 0x7f1c6e3f6704 0x7f1c6e3f6852 0x566d63 0x59fc4e 0x7f1c6e3434ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f1c6e3434ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ### Step-2: Time took to load Images : 0:00:14.353315
# At batch sz : 100
# utils predict Duration: 0:00:29.240614
# ### Step-3: Time took to compute results : 0:00:29.328200
# tcmalloc: large alloc 3010560000 bytes == 0x7f18ca8e8000 @  0x7f1c718fe1e7 0x7f1c6e2f35e1 0x7f1c6e35a420 0x7f1c6e34f7d5 0x7f1c6e3e4497 0x50a635 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f1c714fbb97 0x5b250a
# ...

# %% [markdown]
# ## batch-2:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' -s 6 -e 11 -bf 1 -bfm 1
# Out:
# 6 11
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip
# Using background : 6
# 500
# 1000
# 1500
# 2000
# Using background : 7
# 500
# 1000
# 1500
# 2000
# Using background : 8
# 500
# 1000
# 1500
# 2000
# Using background : 9
# 500
# 1000
# 1500
# 2000
# Using background : 10
# 500
# 1000
# 1500
# 2000
# Duration: 0:04:23.206294
# time: 4min 25s

# %%
os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' -rs 0 -re 5001 -b 100
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' -rs 5001 -re 10001 -b 100
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' -rs 10001 -re 15001 -b 100
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' --start 0 --end 5000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip' -rs 15001 -re 20001 -b 100
# Out:
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:13.117896
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdd636000 @  0x7f4bcf7521e7 0x7f4bcc1475e1 0x7f4bcc1abc78 0x7f4bcc1abd93 0x7f4bcc249ea8 0x7f4bcc24a704 0x7f4bcc24a852 0x566d63 0x59fc4e 0x7f4bcc1974ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f4bcc1974ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ### Step-2: Time took to load Images : 0:00:13.990632
# At batch sz : 100
# utils predict Duration: 0:00:29.039101
# ### Step-3: Time took to compute results : 0:00:29.125817
# tcmalloc: large alloc 3010560000 bytes == 0x7f48268e8000 @  0x7f4bcf7521e7 0x7f4bcc1475e1 0x7f4bcc1ae420 0x7f4bcc1a37d5 0x7f4bcc238497 0x50a635 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f4bcf34fb97 0x5b250a
# ...

# %% [markdown]
# ## Batch-3:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' -s 11 -e 16 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip' -rs 15000 -re 20001 -b 50
# Out:
# 11 16
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip
# Using background : 11
# 500
# 1000
# 1500
# 2000
# Using background : 12
# 500
# 1000
# 1500
# 2000
# Using background : 13
# 500
# 1000
# 1500
# 2000
# Using background : 14
# 500
# 1000
# 1500
# 2000
# Using background : 15
# 500
# 1000
# 1500
# 2000
# Duration: 0:05:56.171288
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:54.931284
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd69f6000 @  0x7fca505a81e7 0x7fca4cf9d5e1 0x7fca4d001c78 0x7fca4d001d93 0x7fca4d09fea8 0x7fca4d0a0704 0x7fca4d0a0852 0x566d63 0x59fc4e 0x7fca4cfed4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7fca4cfed4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-4:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' -s 16 -e 21 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip' -rs 15000 -re 20001 -b 50
# Out:
# 16 21
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip
# Using background : 16
# 500
# 1000
# 1500
# 2000
# Using background : 17
# 500
# 1000
# 1500
# 2000
# Using background : 18
# 500
# 1000
# 1500
# 2000
# Using background : 19
# 500
# 1000
# 1500
# 2000
# Using background : 20
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:50.651383
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:12.617330
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd6238000 @  0x7fa0445a01e7 0x7fa040f955e1 0x7fa040ff9c78 0x7fa040ff9d93 0x7fa041097ea8 0x7fa041098704 0x7fa041098852 0x566d63 0x59fc4e 0x7fa040fe54ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7fa040fe54ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-5:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' -s 21 -e 26 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip' -rs 15000 -re 20001 -b 50
# Out:
# 21 26
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip
# Using background : 21
# 500
# 1000
# 1500
# 2000
# Using background : 22
# 500
# 1000
# 1500
# 2000
# Using background : 23
# 500
# 1000
# 1500
# 2000
# Using background : 24
# 500
# 1000
# 1500
# 2000
# Using background : 25
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:46.194064
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:12.887715
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd62c6000 @  0x7f3ea32751e7 0x7f3e9fc6a5e1 0x7f3e9fccec78 0x7f3e9fcced93 0x7f3e9fd6cea8 0x7f3e9fd6d704 0x7f3e9fd6d852 0x566d63 0x59fc4e 0x7f3e9fcba4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f3e9fcba4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-6:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' -s 26 -e 31 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip' -rs 15000 -re 20001 -b 50
# Out:
# 26 31
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip
# Using background : 26
# 500
# 1000
# 1500
# 2000
# Using background : 27
# 500
# 1000
# 1500
# 2000
# Using background : 28
# 500
# 1000
# 1500
# 2000
# Using background : 29
# 500
# 1000
# 1500
# 2000
# Using background : 30
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:47.615648
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:12.666674
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd5fae000 @  0x7f24d95311e7 0x7f24d5f265e1 0x7f24d5f8ac78 0x7f24d5f8ad93 0x7f24d6028ea8 0x7f24d6029704 0x7f24d6029852 0x566d63 0x59fc4e 0x7f24d5f764ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f24d5f764ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-7:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' -s 31 -e 36 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip' -rs 15000 -re 20001 -b 50
# Out:
# 31 36
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip
# Using background : 31
# 500
# 1000
# 1500
# 2000
# Using background : 32
# 500
# 1000
# 1500
# 2000
# Using background : 33
# 500
# 1000
# 1500
# 2000
# Using background : 34
# 500
# 1000
# 1500
# 2000
# Using background : 35
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:43.370873
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:12.656663
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd7b8c000 @  0x7f11123c61e7 0x7f110edbb5e1 0x7f110ee1fc78 0x7f110ee1fd93 0x7f110eebdea8 0x7f110eebe704 0x7f110eebe852 0x566d63 0x59fc4e 0x7f110ee0b4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f110ee0b4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-8:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' -s 36 -e 41 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip' -rs 15000 -re 20001 -b 50
# Out:
# 36 41
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip
# Using background : 36
# 500
# 1000
# 1500
# 2000
# Using background : 37
# 500
# 1000
# 1500
# 2000
# Using background : 38
# 500
# 1000
# 1500
# 2000
# Using background : 39
# 500
# 1000
# 1500
# 2000
# Using background : 40
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:45.042305
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:12.287774
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd64ae000 @  0x7fadcae581e7 0x7fadc784d5e1 0x7fadc78b1c78 0x7fadc78b1d93 0x7fadc794fea8 0x7fadc7950704 0x7fadc7950852 0x566d63 0x59fc4e 0x7fadc789d4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7fadc789d4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-9:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' -s 41 -e 46 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip' -rs 15000 -re 20001 -b 50
# Out:
# 41 46
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip
# Using background : 41
# 500
# 1000
# 1500
# 2000
# Using background : 42
# 500
# 1000
# 1500
# 2000
# Using background : 43
# 500
# 1000
# 1500
# 2000
# Using background : 44
# 500
# 1000
# 1500
# 2000
# Using background : 45
# 500
# 1000
# 1500
# 2000
# Duration: 0:03:00.329626
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:13.523652
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd627e000 @  0x7fdd5cc511e7 0x7fdd596465e1 0x7fdd596aac78 0x7fdd596aad93 0x7fdd59748ea8 0x7fdd59749704 0x7fdd59749852 0x566d63 0x59fc4e 0x7fdd596964ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7fdd596964ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-10:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' -s 46 -e 51 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip' -rs 15000 -re 20001 -b 50
# Out:
# 46 51
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip
# Using background : 46
# 500
# 1000
# 1500
# 2000
# Using background : 47
# 500
# 1000
# 1500
# 2000
# Using background : 48
# 500
# 1000
# 1500
# 2000
# Using background : 49
# 500
# 1000
# 1500
# 2000
# Using background : 50
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:50.216162
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:12.977349
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xd7c1c000 @  0x7fa0d00ab1e7 0x7fa0ccaa05e1 0x7fa0ccb04c78 0x7fa0ccb04d93 0x7fa0ccba2ea8 0x7fa0ccba3704 0x7fa0ccba3852 0x566d63 0x59fc4e 0x7fa0ccaf04ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7fa0ccaf04ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-11:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' -s 51 -e 56 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip' -rs 15000 -re 20001 -b 50
# Out:
# 51 56
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip
# Using background : 51
# 500
# 1000
# 1500
# 2000
# Using background : 52
# 500
# 1000
# 1500
# 2000
# Using background : 53
# 500
# 1000
# 1500
# 2000
# Using background : 54
# 500
# 1000
# 1500
# 2000
# Using background : 55
# 500
# 1000
# 1500
# 2000
# Duration: 0:03:46.311742
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:23.316186
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xde24e000 @  0x7f3a698db1e7 0x7f3a662d05e1 0x7f3a66334c78 0x7f3a66334d93 0x7f3a663d2ea8 0x7f3a663d3704 0x7f3a663d3852 0x566d63 0x59fc4e 0x7f3a663204ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f3a663204ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-12:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' -s 56 -e 61 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip' -rs 15000 -re 20001 -b 50
# Out:
# 56 61
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip
# Using background : 56
# 500
# 1000
# 1500
# 2000
# Using background : 57
# 500
# 1000
# 1500
# 2000
# Using background : 58
# 500
# 1000
# 1500
# 2000
# Using background : 59
# 500
# 1000
# 1500
# 2000
# Using background : 60
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:08.741556
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:13.591261
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xde330000 @  0x7fa1761c21e7 0x7fa172bb75e1 0x7fa172c1bc78 0x7fa172c1bd93 0x7fa172cb9ea8 0x7fa172cba704 0x7fa172cba852 0x566d63 0x59fc4e 0x7fa172c074ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7fa172c074ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-13:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' -s 61 -e 66 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip' -rs 15000 -re 20001 -b 50
# Out:
# 61 66
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip
# Using background : 61
# 500
# 1000
# 1500
# 2000
# Using background : 62
# 500
# 1000
# 1500
# 2000
# Using background : 63
# 500
# 1000
# 1500
# 2000
# Using background : 64
# 500
# 1000
# 1500
# 2000
# Using background : 65
# 500
# 1000
# 1500
# 2000
# Duration: 0:01:57.559049
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.161711
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdca2a000 @  0x7f7a819581e7 0x7f7a7e34d5e1 0x7f7a7e3b1c78 0x7f7a7e3b1d93 0x7f7a7e44fea8 0x7f7a7e450704 0x7f7a7e450852 0x566d63 0x59fc4e 0x7f7a7e39d4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f7a7e39d4ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-14:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' -s 66 -e 71 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip' -rs 15000 -re 20001 -b 50
# Out:
# 66 71
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip
# Using background : 66
# 500
# 1000
# 1500
# 2000
# Using background : 67
# 500
# 1000
# 1500
# 2000
# Using background : 68
# 500
# 1000
# 1500
# 2000
# Using background : 69
# 500
# 1000
# 1500
# 2000
# Using background : 70
# 500
# 1000
# 1500
# 2000
# Duration: 0:01:58.078352
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.200002
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdc890000 @  0x7fd125c401e7 0x7fd1226355e1 0x7fd122699c78 0x7fd122699d93 0x7fd122737ea8 0x7fd122738704 0x7fd122738852 0x566d63 0x59fc4e 0x7fd1226854ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7fd1226854ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-15:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' -s 71 -e 76 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip' -rs 15000 -re 20001 -b 50
# Out:
# 71 76
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip
# Using background : 71
# 500
# 1000
# 1500
# 2000
# Using background : 72
# 500
# 1000
# 1500
# 2000
# Using background : 73
# 500
# 1000
# 1500
# 2000
# Using background : 74
# 500
# 1000
# 1500
# 2000
# Using background : 75
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:01.204288
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.126858
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdd26e000 @  0x7f8b2746f1e7 0x7f8b23e645e1 0x7f8b23ec8c78 0x7f8b23ec8d93 0x7f8b23f66ea8 0x7f8b23f67704 0x7f8b23f67852 0x566d63 0x59fc4e 0x7f8b23eb44ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f8b23eb44ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-16:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' -s 76 -e 81 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip' -rs 15000 -re 20001 -b 50
# Out:
# 76 81
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip
# Using background : 76
# 500
# 1000
# 1500
# 2000
# Using background : 77
# 500
# 1000
# 1500
# 2000
# Using background : 78
# 500
# 1000
# 1500
# 2000
# Using background : 79
# 500
# 1000
# 1500
# 2000
# Using background : 80
# 500
# 1000
# 1500
# 2000
# Duration: 0:03:49.516628
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:44.894633
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdc082000 @  0x7faa2627e1e7 0x7faa22c735e1 0x7faa22cd7c78 0x7faa22cd7d93 0x7faa22d75ea8 0x7faa22d76704 0x7faa22d76852 0x566d63 0x59fc4e 0x7faa22cc34ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7faa22cc34ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-17:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' -s 81 -e 86 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip' -rs 15000 -re 20001 -b 50
# Out:
# 81 86
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip
# Using background : 81
# 500
# 1000
# 1500
# 2000
# Using background : 82
# 500
# 1000
# 1500
# 2000
# Using background : 83
# 500
# 1000
# 1500
# 2000
# Using background : 84
# 500
# 1000
# 1500
# 2000
# Using background : 85
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:08.975007
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.203215
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdc478000 @  0x7f265de201e7 0x7f265a8155e1 0x7f265a879c78 0x7f265a879d93 0x7f265a917ea8 0x7f265a918704 0x7f265a918852 0x566d63 0x59fc4e 0x7f265a8654ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f265a8654ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-18:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' -s 86 -e 91 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip' -rs 15000 -re 20001 -b 50
# Out:
# 86 91
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip
# Using background : 86
# 500
# 1000
# 1500
# 2000
# Using background : 87
# 500
# 1000
# 1500
# 2000
# Using background : 88
# 500
# 1000
# 1500
# 2000
# Using background : 89
# 500
# 1000
# 1500
# 2000
# Using background : 90
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:07.914934
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.329729
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdd6b6000 @  0x7f122f7a41e7 0x7f122c1995e1 0x7f122c1fdc78 0x7f122c1fdd93 0x7f122c29bea8 0x7f122c29c704 0x7f122c29c852 0x566d63 0x59fc4e 0x7f122c1e94ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f122c1e94ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# ## Batch-19:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
#!python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' -s 91 -e 96 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' -rs 0 -re 5001 -b 50
#!python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' -rs 5000 -re 10001 -b 50
#!python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' -rs 10000 -re 15001 -b 50
#!python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip' -rs 15000 -re 20001 -b 50
# Out:
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.078640
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdcdba000 @  0x7f4d16df31e7 0x7f4d137e85e1 0x7f4d1384cc78 0x7f4d1384cd93 0x7f4d138eaea8 0x7f4d138eb704 0x7f4d138eb852 0x566d63 0x59fc4e 0x7f4d138384ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f4d138384ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ### Step-2: Time took to load Images : 0:00:14.149845
# At batch sz : 50
# utils predict Duration: 0:00:28.767153
# ### Step-3: Time took to compute results : 0:00:28.859785
# tcmalloc: large alloc 3010560000 bytes == 0x7f496e8e8000 @  0x7f4d16df31e7 0x7f4d137e85e1 0x7f4d1384f420 0x7f4d138447d5 0x7f4d138d9497 0x50a635 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7f4d169f0b97 0x5b250a
# ...

# %% [markdown]
# ## Batch-20:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python s15_datasetScript.py -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' -s 96 -e 101 -bf 1 -bfm 1 

os.chdir('/content/drive/My Drive/EVA4/S15/lib/DenseDepth')
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' -rs 0 -re 5001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' --start 0 --end 5001 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' -rs 5000 -re 10001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' --start 0 --end 10000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' -rs 10000 -re 15001 -b 50
# !python test.py --input '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' --start 0 --end 15000 -o '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip' -rs 15000 -re 20001 -b 50
# Out:
# 96 101
# Output is generating at : /content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip
# Using background : 96
# 500
# 1000
# 1500
# 2000
# Using background : 97
# 500
# 1000
# 1500
# 2000
# Using background : 98
# 500
# 1000
# 1500
# 2000
# Using background : 99
# 500
# 1000
# 1500
# 2000
# Using background : 100
# 500
# 1000
# 1500
# 2000
# Duration: 0:02:02.266218
# Using TensorFlow backend.
# Loading model...
# ### Step-1: Time took to load model : 0:00:09.042307
#
# Model loaded (nyu.h5).
# tcmalloc: large alloc 3010560000 bytes == 0xdb91c000 @  0x7f43059541e7 0x7f43023495e1 0x7f43023adc78 0x7f43023add93 0x7f430244bea8 0x7f430244c704 0x7f430244c852 0x566d63 0x59fc4e 0x7f43023994ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x588e5c 0x59fc4e 0x7f43023994ed 0x50a2bf 0x50bfb4 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64 0x509a90 0x50a48d 0x50cd96 0x507d64
#
# Loaded (2500) images of size (224, 224, 3).
# ...

# %% [markdown]
# # Verify the file count in all ZIP files

# %%
from zipfile import ZipFile
batch_1 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip', 'r')
batch_2 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_2.zip', 'r')
batch_3 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_3.zip', 'r')
batch_4 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_4.zip', 'r')
batch_5 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_5.zip', 'r')

batch_6 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_6.zip', 'r')
batch_7 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_7.zip', 'r')
batch_8 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_8.zip', 'r')
batch_9 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_9.zip', 'r')
batch_10 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_10.zip', 'r')

batch_11 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_11.zip', 'r')
batch_12 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_12.zip', 'r')
batch_13 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_13.zip', 'r')
batch_14 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_14.zip', 'r')
batch_15 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_15.zip', 'r')

batch_16 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_16.zip', 'r')
batch_17 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_17.zip', 'r')
batch_18 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_18.zip', 'r')
batch_19 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip', 'r')
batch_20 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_20.zip', 'r')


print('Batch_1 zip file contains : {} files'.format(len(batch_1.namelist())))
print('Batch_2 zip file contains : {} files'.format(len(batch_2.namelist())))
print('Batch_3 zip file contains : {} files'.format(len(batch_3.namelist())))
print('Batch_4 zip file contains : {} files'.format(len(batch_4.namelist())))
print('Batch_5 zip file contains : {} files'.format(len(batch_5.namelist())))

print('Batch_6 zip file contains : {} files'.format(len(batch_6.namelist())))
print('Batch_7 zip file contains : {} files'.format(len(batch_7.namelist())))
print('Batch_8 zip file contains : {} files'.format(len(batch_8.namelist())))
print('Batch_9 zip file contains : {} files'.format(len(batch_9.namelist())))
print('Batch_10 zip file contains : {} files'.format(len(batch_10.namelist())))

print('Batch_11 zip file contains : {} files'.format(len(batch_11.namelist())))
print('Batch_12 zip file contains : {} files'.format(len(batch_12.namelist())))
print('Batch_13 zip file contains : {} files'.format(len(batch_13.namelist())))
print('Batch_14 zip file contains : {} files'.format(len(batch_14.namelist())))
print('Batch_15 zip file contains : {} files'.format(len(batch_15.namelist())))

print('Batch_16 zip file contains : {} files'.format(len(batch_16.namelist())))
print('Batch_17 zip file contains : {} files'.format(len(batch_17.namelist())))
print('Batch_18 zip file contains : {} files'.format(len(batch_18.namelist())))
print('Batch_19 zip file contains : {} files'.format(len(batch_19.namelist())))
print('Batch_20 zip file contains : {} files'.format(len(batch_20.namelist())))



total = [len(i.namelist()) for i in [batch_1,batch_2,batch_3,batch_4,batch_5,batch_6,batch_7,batch_8,batch_9,batch_10,batch_11,batch_12,batch_13,batch_14,batch_15,batch_16,batch_17,batch_18,batch_19,batch_20]]
print('Total Number of files present in dataset : {}'.format(sum(total)))

del batch_1,batch_2,batch_3,batch_4,batch_5,batch_6,batch_7,batch_8,batch_9,batch_10,batch_11,batch_12,batch_13,batch_14,batch_15,batch_16,batch_17,batch_18,batch_19,batch_20
# Out:
# Batch_1 zip file contains : 30001 files
# Batch_2 zip file contains : 30001 files
# Batch_3 zip file contains : 30001 files
# Batch_4 zip file contains : 30001 files
# Batch_5 zip file contains : 30001 files
# Batch_6 zip file contains : 30001 files
# Batch_7 zip file contains : 30001 files
# Batch_8 zip file contains : 30001 files
# Batch_9 zip file contains : 30001 files
# Batch_10 zip file contains : 30001 files
# Batch_11 zip file contains : 30001 files
# Batch_12 zip file contains : 30001 files
# Batch_13 zip file contains : 30001 files
# Batch_14 zip file contains : 30001 files
# Batch_15 zip file contains : 30001 files
# Batch_16 zip file contains : 30001 files
# Batch_17 zip file contains : 30001 files
# Batch_18 zip file contains : 30001 files
# Batch_19 zip file contains : 30001 files
# Batch_20 zip file contains : 30001 files
# Total Number of files present in dataset : 600020
# time: 40.7 s

# %%
from zipfile import ZipFile
batch_15 = ZipFile('/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_19.zip', 'r')
print('Batch_15 zip file contains : {} files'.format(len(batch_15.namelist())))
# Out:
# Batch_15 zip file contains : 30001 files
# time: 189 ms

# %% [markdown]
# # pickle file generation:

# %%
os.chdir(os.path.join(scriptsPath,'pythonFiles'))
# !python generatePkl_fromCustomDataset.py -i '/content/drive/My Drive/EVA4/S15/dataset/zipFiles/batch_1.zip' -o '/content/drive/My Drive/EVA4/S15/dataset/pklFiles/batch_1' -s 0 -e 30001
# Out:
# tcmalloc: large alloc 1218068480 bytes == 0x16fef8000 @  0x7eff6c99c2a4 0x591d67 0x4dd6a7 0x4e2ac0 0x4e210a 0x4e0d98 0x4e251b 0x4e227f 0x4e293c 0x4e3386 0x45441a 0x50a3ea 0x50cd96 0x5060d4 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7eff6c598b97 0x5b250a
# tcmalloc: large alloc 1827209216 bytes == 0x1b889c000 @  0x7eff6c99c2a4 0x591d67 0x4dd6a7 0x4e2ac0 0x4e210a 0x4e0d98 0x4e251b 0x4e22ab 0x4e293c 0x4e3386 0x45441a 0x50a3ea 0x50cd96 0x5060d4 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7eff6c598b97 0x5b250a
# tcmalloc: large alloc 2741035008 bytes == 0x22572c000 @  0x7eff6c99c2a4 0x591d67 0x4dd6a7 0x4e2ac0 0x4e210a 0x4e0d98 0x4e251b 0x4e238f 0x4e2990 0x4e3386 0x45441a 0x50a3ea 0x50cd96 0x5060d4 0x50a48d 0x50bfb4 0x507d64 0x50ae13 0x634c82 0x634d37 0x6384ef 0x639091 0x4b0d00 0x7eff6c598b97 0x5b250a
# ...

# %%
# !ls -ltrh '/content/drive/My Drive/EVA4/S15/dataset/pklFiles'
# Out:
# total 14M
# -rw------- 1 root root  14M May 18 10:10 data_batch_64_test.tar.gz
# drwx------ 2 root root 4.0K May 18 10:11 data_batch_64_test
# -rw------- 1 root root    0 May 25 06:37 batch_1
# time: 6.06 s
